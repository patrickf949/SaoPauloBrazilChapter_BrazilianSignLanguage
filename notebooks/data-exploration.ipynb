# %% [markdown]
# # Data exploration
#
# This notebook was created to explore the metadata extracted from the dataset we are using, as well as a comparison between the datasets.

# %%
import pandas as pd
import os

# %%
# Change working directory to the project root directory
current_dir = os.getcwd()
os.chdir(current_dir + "/../")
os.getcwd()
# Out:
# '/Users/gustavosantos/code/omdena/SaoPauloBrazilChapter_BrazilianSignLanguage'

# %%
def text_normalization(text):
    text = text.lower()
    text = text.strip()
    text = text.replace("\n", " ")
    text = text.replace("\r", " ")
    text = text.replace("\t", " ")
    text = text.replace("-", " ")
    text = text.replace(" ", "_")
    return text

# %%
BASE_DIR = os.getcwd() + "/data/raw/"

# Set paths to the raw data files
ne_path = BASE_DIR + "INES/"
sb_path = BASE_DIR + "SignBank/"
uf_path = BASE_DIR + "UFV/"
vl_path = BASE_DIR + "V-Librasil/"

# %%
try:
    ne_raw_df = pd.read_csv(ne_path + "metadata.csv")
except FileNotFoundError:
    print("INES metadata not found")

try:
    sb_raw_df = pd.read_csv(sb_path + "metadata.csv")
except FileNotFoundError:
    print("SignBank metadata not found")

try:
    uf_raw_df = pd.read_csv(uf_path + "metadata.csv")
except FileNotFoundError:
    print("UFV metadata not found")

try:
    vl_raw_df = pd.read_csv(vl_path + "metadata.csv")
except FileNotFoundError:
    print("V-Librasil metadata not found")
# Out:
# UFV metadata not found

# %% [markdown]
# ## INES dataset

# %%
display(ne_raw_df.head())
display(ne_raw_df.tail())
# Out:
#      label scraped_label  number_in_label  \
# 0        A             A            False
# 1  ABACATE       ABACATE            False
# 2  ABACAXI       ABACAXI            False
# 3   ABAFAR        ABAFAR            False
# 4   ABAIXO        ABAIXO            False
#
#                                            video_url  file_exists letter  \
# 0  https://www.ines.gov.br/dicionario-de-libras/p...         True      A
# 1  https://www.ines.gov.br/dicionario-de-libras/p...         True      A
# 2  https://www.ines.gov.br/dicionario-de-libras/p...         True      A
# 3  https://www.ines.gov.br/dicionario-de-libras/p...         True      A
# 4  https://www.ines.gov.br/dicionario-de-libras/p...         True      A
#
#   assuntos                                            acepção  \
# 0   NENHUM  Primeira letra do alfabeto da língua portugues...
# 1    FRUTA  O fruto do abacateiro. Comestível, tem a polpa...
# 2    FRUTA  Fruta de casca grossa e áspera. Sua polpa pode...
# 3   NENHUM             Cobrir ou fechar, para manter o calor.
# 4   NENHUM  Lugar, posição ou situação inferior, em relaçã...
#
#                                              exemplo  \
# 0  Invente qualquer palavra que comece com a letr...
# 1                   Você gosta de abacate com leite?
# 2      Hoje tomei suco de abacaxi, ele estava ácido.
# 3  Se você quer abafar seu quarto, é melhor fecha...
# 4  Não é no primeiro apartamento abaixo, é no seg...
#
#                                       exemplo libras classe gramatical  \
# 0          VOCÊ INVENTAR QUALQUER PALAVRA COMEÇAR A.       SUBSTANTIVO
# 1                   VOCÊ GOSTAR ABACATE LEITE JUNTO?       SUBSTANTIVO
# 2                  HOJE S-U-C-O ABACAXI BEBER ÁCID@.       SUBSTANTIVO
# 3  S-I VOCÊ QUERER QUARTO SE@ ABAFAR A-R? MELHOR ...             VERBO
# 4           APARTAMENTO PRIMEIR@ NÃO SEGUND@ ABAIXO.              ADV.
#
#      origem
# 0  Nacional
# 1  Nacional
# 2  Nacional
# 3  Nacional
# 4  Nacional
#              label scraped_label  number_in_label  \
# 5814  ZIGUEZAGUEAR  ZIGUEZAGUEAR            False
# 5815         ZÍPER         ZÍPER            False
# 5816        ZOMBAR        ZOMBAR            False
# 5817     ZOOLÓGICO     ZOOLÓGICO            False
# 5818           ZUM           ZUM            False
#
#                                               video_url  file_exists letter  \
# 5814  https://www.ines.gov.br/dicionario-de-libras/p...         True    NaN
# 5815  https://www.ines.gov.br/dicionario-de-libras/p...         True    NaN
# 5816  https://www.ines.gov.br/dicionario-de-libras/p...         True    NaN
# 5817  https://www.ines.gov.br/dicionario-de-libras/p...         True    NaN
# 5818  https://www.ines.gov.br/dicionario-de-libras/p...         True    NaN
#
#                     assuntos  \
# 5814                  NENHUM
# 5815  VESTUÁRIO/COMPLEMENTOS
# 5816                  NENHUM
# 5817                  NENHUM
# 5818                  NENHUM
#
#                                                 acepção  \
# 5814         Fazer ziguezagues; andar em linha sinuosa.
# 5815  Duas tiras de pano que fecham uma abertura. Pa...
# 5816      Fazer zombaria em relação a algo ou a alguém.
# 5817  Local onde diversas espécies animais são criad...
# 5818  Conjunto de lentes que se ajustam para oferece...
#
#                                                 exemplo  \
# 5814  O ônibus tentou frear, mas saiu ziguezagueando...
# 5815  Olhe lá, o zíper atrás do vestido daquela mulh...
# 5816  Eu cai na escada do shopping e as pessoas zomb...
# 5817  Todo os domingos vou ao zoológico com minha fa...
# 5818  Eu quero comprar uma máquina fotográfica que t...
#
#                                          exemplo libras classe gramatical  \
# 5814  PISTA MOLHAD@ MOTORISTA ÔNIBUS FREAR veículoZI...             VERBO
# 5815        OLHÁR LÁ MULHER VESTIDO ATRÁS ZÍPER ABERT@.       SUBSTANTIVO
# 5816  S-H-O-P-P-I-N-G EU ESCADA pessoaCAIR PESSOA 2p...             VERBO
# 5817       TOD@ DOMINGO IR JUNTO ME@ FAMÍLIA VER Z-Ô-O.          ADJETIVO
# 5818  AGORA MÁQUINA-FOTOGRAFIA MODERN@ ZUM EU QUERER...       SUBSTANTIVO
#
#         origem
# 5814  Nacional
# 5815  Nacional
# 5816  Nacional
# 5817  Nacional
# 5818  Nacional

# %% [markdown]
# The output obove shows that there was a bug while extracting some letters, this is easily fixed

# %%
# Add first label letter to missing values in the 'letter' column

ne_raw_df["letter"] = ne_raw_df["letter"].fillna(ne_raw_df["label"].str[0])

# %%
print(f"# of INES samples: {ne_raw_df.shape[0]}")
print(f"# of INES columns: {ne_raw_df.shape[1]}")
# Out:
# # of INES samples: 5819
# # of INES columns: 12

# %%
ne_raw_df.columns
# Out:
# Index(['label', 'scraped_label', 'number_in_label', 'video_url', 'file_exists',
#        'letter', 'assuntos', 'acepção', 'exemplo', 'exemplo libras',
#        'classe gramatical', 'origem'],
#       dtype='object')

# %%
print(
    f"Percentage of file existence in INES dataset: {(ne_raw_df['file_exists'].sum() / ne_raw_df.shape[0]):.2%}"
)
# Out:
# Percentage of file existence in INES dataset: 93.97%

# %%
# Remove rows where the file does not exist
ne_df = ne_raw_df[ne_raw_df["file_exists"]]

# %%
print(f"# of INES duplicate rows: {ne_df.duplicated().sum()}")
# Out:
# # of INES duplicate rows: 40

# %%
# Sort for easier analysis
ne_df[ne_df["scraped_label"].duplicated(keep=False)].head(10).sort_values("label")
# Out:
#          label scraped_label  number_in_label  \
# 1273   CHINELO       CHINELO            False
# 1274   CHINELO       CHINELO            False
# 1981      DOIS         DOIS2             True
# 1982      DOIS         DOIS2             True
# 4304    POESIA        POESIA            False
# 4305    POESIA        POESIA            False
# 5760         Z             Z            False
# 5761      ZAGA          ZAGA            False
# 5762  ZAGUEIRO      ZAGUEIRO            False
# 5763   ZANGADO       ZANGADO            False
#
#                                               video_url  file_exists letter  \
# 1273  https://www.ines.gov.br/dicionario-de-libras/p...         True      C
# 1274  https://www.ines.gov.br/dicionario-de-libras/p...         True      C
# 1981  https://www.ines.gov.br/dicionario-de-libras/p...         True      D
# 1982  https://www.ines.gov.br/dicionario-de-libras/p...         True      D
# 4304  https://www.ines.gov.br/dicionario-de-libras/p...         True      P
# 4305  https://www.ines.gov.br/dicionario-de-libras/p...         True      P
# 5760  https://www.ines.gov.br/dicionario-de-libras/p...         True      Z
# 5761  https://www.ines.gov.br/dicionario-de-libras/p...         True      Z
# 5762  https://www.ines.gov.br/dicionario-de-libras/p...         True      Z
# 5763  https://www.ines.gov.br/dicionario-de-libras/p...         True      Z
#
#                     assuntos  \
# 1273  VESTUÁRIO/COMPLEMENTOS
# 1274  VESTUÁRIO/COMPLEMENTOS
# 1981        NUMERAL/DINHEIRO
# 1982        NUMERAL/DINHEIRO
# 4304                  NENHUM
# 4305                  NENHUM
# 5760                  NENHUM
# 5761        ESPORTE/DIVERSÃO
# 5762        ESPORTE/DIVERSÃO
# 5763                  NENHUM
#
#                                                 acepção  \
# 1273  Calçado especial para uso doméstico, praia e a...
# 1274  Calçado especial para uso doméstico, praia e a...
# 1981  Cardinal dos conjuntos equivalentes a um conju...
# 1982  Cardinal dos conjuntos equivalentes a um conju...
# 4304  A arte do ouvinte que escreve versos; a compos...
# 4305  A arte do ouvinte que escreve versos; a compos...
# 5760  Sinal gráfico elementar com que se representam...
# 5761             Posição de defesa, no jogo de futebol.
# 5762  Jogador de futebol que desempenha sua função d...
# 5763        Aquele que se zangou; aborrecido; irritado.
#
#                                                 exemplo  \
# 1273                    Eu sempre uso chinelo na praia.
# 1274                    Eu sempre uso chinelo na praia.
# 1981                               Ela tem dois filhos.
# 1982                               Ela tem dois filhos.
# 4304               Tem tem um livro de poesia? Vou ler.
# 4305               Tem tem um livro de poesia? Vou ler.
# 5760  No português tem poucas palavras que começam c...
# 5761          A zaga do Vasco está fraca, sempre perde.
# 5762  O zagueiro número três do Brasil é muito descu...
# 5763  O professor está zangado porque você faltou à ...
#
#                                     exemplo libras classe gramatical    origem
# 1273                      EU PRAIA SEMPRE CHINELO.       SUBSTANTIVO  Nacional
# 1274                      EU PRAIA SEMPRE CHINELO.       SUBSTANTIVO  Nacional
# 1981                              EL@ TER FILH@ 2.              NUM.  Nacional
# 1982                              EL@ TER FILH@ 2.              NUM.  Nacional
# 4304                LIVRO POESIA VOCÊ TER? EU LER.       SUBSTANTIVO  Nacional
# 4305                LIVRO POESIA VOCÊ TER? EU LER.       SUBSTANTIVO  Nacional
# 5760  PORTUGUÊS TER PALAVRA POUC@ COMEÇAR LETRA Z.       SUBSTANTIVO  Nacional
# 5761               VASCO ZAGA FRAC@ SEMPRE PERDER.       SUBSTANTIVO  Nacional
# 5762       BRASIL ZAQUEIRO NÚMERO 3 DESCUID@muito.       SUBSTANTIVO  Nacional
# 5763    PROFESSOR@ ZANGAD@ VOCÊ ONTEM AULA FALTAR.          ADJETIVO  Nacional

# %% [markdown]
# The output above shows that the duplicated entries in the data are not the homographs we're look for. These are simply bugged duplicated entries. Further checking the [dataset website](https://www.ines.gov.br/dicionario-de-libras/), it was possible to check that homograph labels have a numeric entry to them, just like WORD1 and WORD2.

# %%
# Get entries that have a number in the label
ne_df = ne_df.drop_duplicates(keep="first")
print(
    f"Number of labels that have more than one appearance: {ne_df[ne_df['number_in_label']].shape[0]}"
)
# Out:
# Number of labels that have more than one appearance: 1343

# %%
ne_df["label"] = ne_df["label"].apply(text_normalization)

# %%
ne_df.head()
# Out:
#      label scraped_label  number_in_label  \
# 0        a             A            False
# 1  abacate       ABACATE            False
# 2  abacaxi       ABACAXI            False
# 3   abafar        ABAFAR            False
# 4   abaixo        ABAIXO            False
#
#                                            video_url  file_exists letter  \
# 0  https://www.ines.gov.br/dicionario-de-libras/p...         True      A
# 1  https://www.ines.gov.br/dicionario-de-libras/p...         True      A
# 2  https://www.ines.gov.br/dicionario-de-libras/p...         True      A
# 3  https://www.ines.gov.br/dicionario-de-libras/p...         True      A
# 4  https://www.ines.gov.br/dicionario-de-libras/p...         True      A
#
#   assuntos                                            acepção  \
# 0   NENHUM  Primeira letra do alfabeto da língua portugues...
# 1    FRUTA  O fruto do abacateiro. Comestível, tem a polpa...
# 2    FRUTA  Fruta de casca grossa e áspera. Sua polpa pode...
# 3   NENHUM             Cobrir ou fechar, para manter o calor.
# 4   NENHUM  Lugar, posição ou situação inferior, em relaçã...
#
#                                              exemplo  \
# 0  Invente qualquer palavra que comece com a letr...
# 1                   Você gosta de abacate com leite?
# 2      Hoje tomei suco de abacaxi, ele estava ácido.
# 3  Se você quer abafar seu quarto, é melhor fecha...
# 4  Não é no primeiro apartamento abaixo, é no seg...
#
#                                       exemplo libras classe gramatical  \
# 0          VOCÊ INVENTAR QUALQUER PALAVRA COMEÇAR A.       SUBSTANTIVO
# 1                   VOCÊ GOSTAR ABACATE LEITE JUNTO?       SUBSTANTIVO
# 2                  HOJE S-U-C-O ABACAXI BEBER ÁCID@.       SUBSTANTIVO
# 3  S-I VOCÊ QUERER QUARTO SE@ ABAFAR A-R? MELHOR ...             VERBO
# 4           APARTAMENTO PRIMEIR@ NÃO SEGUND@ ABAIXO.              ADV.
#
#      origem
# 0  Nacional
# 1  Nacional
# 2  Nacional
# 3  Nacional
# 4  Nacional

# %% [markdown]
# ## SignBank

# %%
sb_raw_df.columns
# Out:
# Index(['label', 'video_url', 'signer_number', 'scraped_label',
#        'scraped_video_url', 'sign_variant', 'signer_number.1',
#        'video_url_root', 'video_url_ext', 'number_in_label'],
#       dtype='object')

# %%
sb_raw_df.head()
# Out:
#        label                                          video_url  \
# 0      À-TOA  https://videos.nals.cce.ufsc.br/SignBank/Vídeo...
# 1    À-VISTA  https://videos.nals.cce.ufsc.br/SignBank/Vídeo...
# 2    ABACAXI  https://videos.nals.cce.ufsc.br/SignBank/Vídeo...
# 3     ABANAR  https://videos.nals.cce.ufsc.br/SignBank/Vídeo...
# 4  ABANDONAR  https://videos.nals.cce.ufsc.br/SignBank/V%C3%...
#
#    signer_number scraped_label  \
# 0              2         À-TOA
# 1              2       À-VISTA
# 2              2       ABACAXI
# 3              2        ABANAR
# 4              1     ABANDONAR
#
#                                    scraped_video_url  sign_variant  \
# 0  https://levantelab.storage.googleapis.com/libr...             1
# 1  https://levantelab.storage.googleapis.com/libr...             1
# 2  https://levantelab.storage.googleapis.com/libr...             1
# 3  https://levantelab.storage.googleapis.com/libr...             1
# 4  https://videos.nals.cce.ufsc.br/SignBank/V%C3%...             1
#
#    signer_number.1 video_url_root video_url_ext  number_in_label
# 0                2     levantelab           mp4            False
# 1                2     levantelab           mp4            False
# 2                2     levantelab           mp4            False
# 3                2     levantelab           mp4            False
# 4                1         videos           mp4            False

# %% [markdown]
# The SignBank dataset and `SignBank/metadata.csv` were processed in a way a `number_in_label` column was defined. This column will help us focus on possible homographs.

# %%
sb_raw_df.duplicated().sum()
# Out:
# 0

# %%
sb_df = sb_raw_df.drop_duplicates(keep="first")
sb_df["label"] = sb_df["label"].apply(text_normalization)

# %%
sb_df.head()
# Out:
#        label                                          video_url  \
# 0      à_toa  https://videos.nals.cce.ufsc.br/SignBank/Vídeo...
# 1    à_vista  https://videos.nals.cce.ufsc.br/SignBank/Vídeo...
# 2    abacaxi  https://videos.nals.cce.ufsc.br/SignBank/Vídeo...
# 3     abanar  https://videos.nals.cce.ufsc.br/SignBank/Vídeo...
# 4  abandonar  https://videos.nals.cce.ufsc.br/SignBank/V%C3%...
#
#    signer_number scraped_label  \
# 0              2         À-TOA
# 1              2       À-VISTA
# 2              2       ABACAXI
# 3              2        ABANAR
# 4              1     ABANDONAR
#
#                                    scraped_video_url  sign_variant  \
# 0  https://levantelab.storage.googleapis.com/libr...             1
# 1  https://levantelab.storage.googleapis.com/libr...             1
# 2  https://levantelab.storage.googleapis.com/libr...             1
# 3  https://levantelab.storage.googleapis.com/libr...             1
# 4  https://videos.nals.cce.ufsc.br/SignBank/V%C3%...             1
#
#    signer_number.1 video_url_root video_url_ext  number_in_label
# 0                2     levantelab           mp4            False
# 1                2     levantelab           mp4            False
# 2                2     levantelab           mp4            False
# 3                2     levantelab           mp4            False
# 4                1         videos           mp4            False

# %%
print(f"# of SignBank samples: {sb_df.shape[0]}")
print(f"# of SignBank unique labels: {sb_df['label'].nunique()}")
print(
    f"# of SignBank possible homographs: {sb_df['label'].duplicated(keep=False).sum()}"
)
# Out:
# # of SignBank samples: 3084
# # of SignBank unique labels: 2510
# # of SignBank possible homographs: 1010

# %% [markdown]
# ## V-Librasil

# %%
vl_raw_df.head(5)
# Out:
#            label  signer_number  \
# 0  À noite toda               1
# 1  À noite toda               3
# 2  À noite toda               2
# 3  À tarde toda               1
# 4  À tarde toda               2
#
#                                            video_url  \
# 0  https://libras.cin.ufpe.br/storage/videos/2021...
# 1  https://libras.cin.ufpe.br/storage/videos/2021...
# 2  https://libras.cin.ufpe.br/storage/videos/2021...
# 3  https://libras.cin.ufpe.br/storage/videos/2020...
# 4  https://libras.cin.ufpe.br/storage/videos/2020...
#
#                               sign_url  signer_order
# 0  https://libras.cin.ufpe.br/sign/885           132
# 1  https://libras.cin.ufpe.br/sign/885           132
# 2  https://libras.cin.ufpe.br/sign/885           132
# 3  https://libras.cin.ufpe.br/sign/100           123
# 4  https://libras.cin.ufpe.br/sign/100           123

# %%
vl_raw_df.duplicated().sum()
# Out:
# 0

# %%
vl_df = vl_raw_df.drop_duplicates(keep="first")
vl_df["label"] = vl_df["label"].apply(text_normalization)

# %%
vl_df.head()
# Out:
#           label  signer_number  \
# 0  à_noite_toda              1
# 1  à_noite_toda              3
# 2  à_noite_toda              2
# 3  à_tarde_toda              1
# 4  à_tarde_toda              2
#
#                                            video_url  \
# 0  https://libras.cin.ufpe.br/storage/videos/2021...
# 1  https://libras.cin.ufpe.br/storage/videos/2021...
# 2  https://libras.cin.ufpe.br/storage/videos/2021...
# 3  https://libras.cin.ufpe.br/storage/videos/2020...
# 4  https://libras.cin.ufpe.br/storage/videos/2020...
#
#                               sign_url  signer_order
# 0  https://libras.cin.ufpe.br/sign/885           132
# 1  https://libras.cin.ufpe.br/sign/885           132
# 2  https://libras.cin.ufpe.br/sign/885           132
# 3  https://libras.cin.ufpe.br/sign/100           123
# 4  https://libras.cin.ufpe.br/sign/100           123

# %%
print(f"# of V-Librasil samples: {vl_df.shape[0]}")
print(f"# of V-Librasil unique labels: {vl_df['label'].nunique()}")
# Out:
# # of V-Librasil samples: 4089
# # of V-Librasil unique labels: 1364

# %% [markdown]
# To check if there are any possible inner dataset homographs, I'll get the label and signer order and set it as an unique identifier to the entry. If the number of unique IDs is different from the number of unique labels, there are some words that could be homographs in the dataset.

# %%
vl_df["entry_id"] = vl_df["label"].astype(str) + "_" + vl_df["signer_order"].astype(str)
vl_df["entry_id"].nunique()
# Out:
# 1364

# %% [markdown]
# ## Combined vocab

# %%
ne_vocab = ne_df["label"].unique()
sb_vocab = sb_df["label"].unique()
vl_vocab = vl_df["label"].unique()

# Get the intersection of the vocabularies
combined_vocab = set(ne_vocab) & set(sb_vocab) & set(vl_vocab)
print(f"Combined vocabulary size: {len(combined_vocab)}")
# Out:
# Combined vocabulary size: 494

# %%
word_count = {}
for word in combined_vocab:
    word_dict = {}
    word_dict["INES"] = ne_df[ne_df["label"] == word].shape[0]
    word_dict["SignBank"] = sb_df[sb_df["label"] == word].shape[0]
    word_dict["V-Librasil"] = vl_df[vl_df["label"] == word].shape[0]
    word_dict["total"] = (
        ne_df[ne_df["label"] == word].shape[0]
        + sb_df[sb_df["label"] == word].shape[0]
        + vl_df[vl_df["label"] == word].shape[0]
    )
    word_count[word] = word_dict

# %%
word_count_df = pd.DataFrame(word_count).T
word_count_df = word_count_df.sort_values("total", ascending=False)
word_count_df = word_count_df.reset_index(drop=False)
word_count_df = word_count_df.rename(columns={"index": "word"})

# %%
word_count_df
# Out:
#           word  INES  SignBank  V-Librasil  total
# 0         mais     6         4           3     13
# 1        cheio     7         3           3     13
# 2        parar     5         2           3     10
# 3           ir     6         1           3     10
# 4          dia     4         3           3     10
# ..         ...   ...       ...         ...    ...
# 489    federal     1         1           3      5
# 490     quente     1         1           3      5
# 491   dinheiro     1         1           3      5
# 492   biscoito     1         1           3      5
# 493  solicitar     1         1           2      4
#
# [494 rows x 5 columns]

# %% [markdown]
# Let's check an example from these words to see if there could be words that mean different things.

# %%
for _, row in ne_df[ne_df["label"] == "mais"].iterrows():
    print(row["acepção"])
    print(row["video_url"])
# Out:
# O que supera o outro em alguma condição ou característica.
# https://www.ines.gov.br/dicionario-de-libras/public/media/palavras/videos/mais1Sm_Prog001.mp4
# O que indica acréscimo; o mesmo que somar; designativo de adição.
# https://www.ines.gov.br/dicionario-de-libras/public/media/palavras/videos/mais2Sm_Prog001.mp4
# De novo; outra vez.
# https://www.ines.gov.br/dicionario-de-libras/public/media/palavras/videos/mais3Sm_Prog001.mp4
# O que tem maior valor.
# https://www.ines.gov.br/dicionario-de-libras/public/media/palavras/videos/mais4Sm_Prog001.mp4
# Representação de maior trajeto ou distância.
# https://www.ines.gov.br/dicionario-de-libras/public/media/palavras/videos/mais5Sm_Prog001.mp4
# O que ainda falta e deve ser acrescentado.
# https://www.ines.gov.br/dicionario-de-libras/public/media/palavras/videos/mais6Sm_Prog001.mp4

# %% [markdown]
# All these videos have different signs and, from the portuguese description, slightly different meanings. This is a case of word that will need a further analysis.

# %%
combined_vocab
# Out:
# {'abacaxi',
#  'abanar',
#  'abandonar',
#  'abelha',
#  'abençoar',
#  'acabar',
#  'aceitar',
#  'acidente',
#  'acompanhar',
#  'aconselhar',
#  'acontecer',
#  'acrescentar',
#  'adulto',
#  'agora',
#  'ainda',
#  'ajudar',
#  'alce',
#  'alfinete',
#  'alto',
#  'amanhã',
#  'amarelo',
#  'amigo',
#  'animal',
#  'aniversário',
#  'ano',
#  'antes',
#  'aparelho_auditivo',
#  'aprender',
#  'ar',
#  'aranha',
#  'assim',
#  'assistir',
#  'associação',
#  'assumir',
#  'atônito',
#  'aumentar',
#  'avaliar',
#  'avião',
#  'azul',
#  'baleia',
#  'balão',
#  'banana',
#  'banheiro',
#  'barato',
#  'barba',
#  'barco',
#  'barulho',
#  'batata',
#  'bebê',
#  'bem',
#  'biblioteca',
#  'bicicleta',
#  'bigode',
#  'biscoito',
#  'bloquear',
#  'bobo',
#  'bocejar',
#  'bode',
#  'boi',
#  'bola',
#  'bolo',
#  'bolsa',
#  'bombeiro',
#  'bonito',
#  'borboleta',
#  'borracha',
#  'bota',
#  'branco',
#  'brilhar',
#  'brinco',
#  'cabelo',
#  'cabeça',
#  'cada',
#  'café',
#  'cair',
#  'caixa',
#  'calculadora',
#  'calça',
#  'cama',
#  'campainha',
#  'campeão',
#  'cancelar',
#  'canguru',
#  'capacete',
#  'capital',
#  'careca',
#  'carne',
#  'caro',
#  'carro',
#  'casa',
#  'casaco',
#  'casamento',
#  'católico',
#  'cavalo',
#  'cebola',
#  'cego',
#  'centro',
#  'cerveja',
#  'chapéu',
#  'chave',
#  'chefe',
#  'chegar',
#  'cheio',
#  'chocolate',
#  'chá',
#  'cidade',
#  'cigarro',
#  'claro',
#  'coelho',
#  'cola',
#  'colocar',
#  'com_licença',
#  'comer',
#  'começar',
#  'como',
#  'comparar',
#  'compreender',
#  'computador',
#  'comunicar',
#  'concordar',
#  'contato',
#  'contra',
#  'cor',
#  'coração',
#  'corpo',
#  'cortar',
#  'costurar',
#  'crescer',
#  'criar',
#  'cueca',
#  'cuidado',
#  'cultura',
#  'curioso',
#  'cuspir',
#  'céu',
#  'círculo',
#  'dar',
#  'deixar',
#  'demitir',
#  'democracia',
#  'desafio',
#  'descobrir',
#  'desenvolver',
#  'desistir',
#  'destruir',
#  'deus',
#  'dia',
#  'dicionário',
#  'difícil',
#  'diminuir',
#  'dinheiro',
#  'dinossauro',
#  'direito',
#  'direto',
#  'dirigir',
#  'disciplina',
#  'dividir',
#  'doce',
#  'documento',
#  'doente',
#  'dólar',
#  'elefante',
#  'elevador',
#  'embaixo',
#  'encontrar',
#  'enganar',
#  'engraçado',
#  'ensinar',
#  'entrar',
#  'escola',
#  'escolher',
#  'escrever',
#  'espelho',
#  'esperar',
#  'esquecer',
#  'estado',
#  'estranho',
#  'estrela',
#  'evitar',
#  'experiência',
#  'explicar',
#  'explodir',
#  'faca',
#  'faculdade',
#  'falhar',
#  'família',
#  'fantasma',
#  'fechar',
#  'federal',
#  'feio',
#  'feliz',
#  'festa',
#  'filho',
#  'filme',
#  'fim',
#  'flauta',
#  'flor',
#  'fogo',
#  'foguete',
#  'fome',
#  'fora',
#  'forte',
#  'fraco',
#  'frio',
#  'futebol',
#  'futuro',
#  'física',
#  'galo',
#  'garfo',
#  'garganta',
#  'gastar',
#  'gato',
#  'gay',
#  'geração',
#  'gorila',
#  'gostar',
#  'governo',
#  'gramática',
#  'gravata',
#  'gritar',
#  'guarda_chuva',
#  'guerra',
#  'helicóptero',
#  'história',
#  'homem',
#  'hora',
#  'hospital',
#  'idoso',
#  'ignorar',
#  'igreja',
#  'imaginar',
#  'impossível',
#  'imprimir',
#  'independente',
#  'inocente',
#  'internet',
#  'ir',
#  'jacaré',
#  'janela',
#  'jovem',
#  'lado',
#  'lavar',
#  'legenda',
#  'leite',
#  'leste',
#  'levar',
#  'leve',
#  'leão',
#  'limite',
#  'livro',
#  'lobo',
#  'longe',
#  'louco',
#  'lua',
#  'lápis',
#  'lésbica',
#  'macaco',
#  'macio',
#  'maconha',
#  'madeira',
#  'maior',
#  'maioria',
#  'mais',
#  'manhã',
#  'manteiga',
#  'marrom',
#  'mas',
#  'matar',
#  'matemática',
#  'meio',
#  'melhor',
#  'memorizar',
#  'menstruar',
#  'metrô',
#  'mil',
#  'milho',
#  'milhão',
#  'minuto',
#  'misturar',
#  'mochila',
#  'moeda',
#  'montanha',
#  'morango',
#  'motivo',
#  'motor',
#  'mudar',
#  'muito',
#  'mulher',
#  'mundo',
#  'máscara',
#  'máximo',
#  'música',
#  'nada',
#  'nadar',
#  'namorar',
#  'nariz',
#  'nascer',
#  'natal',
#  'negativo',
#  'nervoso',
#  'noite',
#  'nome',
#  'nove',
#  'novo',
#  'nunca',
#  'não',
#  'objetivo',
#  'ocupado',
#  'oeste',
#  'oficina',
#  'oi',
#  'onde',
#  'ontem',
#  'opinião',
#  'outro',
#  'ouvir',
#  'ovelha',
#  'pagar',
#  'pai',
#  'papel',
#  'parar',
#  'parecer',
#  'parede',
#  'passado',
#  'passar',
#  'pato',
#  'país',
#  'pedir',
#  'pegar',
#  'peixe',
#  'pente',
#  'pequeno',
#  'perceber',
#  'perfeito',
#  'perfume',
#  'perigo',
#  'perspectiva',
#  'perto',
#  'pesado',
#  'pessoa',
#  'piano',
#  'pior',
#  'pipoca',
#  'pizza',
#  'plástico',
#  'pobre',
#  'poder',
#  'poesia',
#  'política',
#  'ponte',
#  'por_favor',
#  'porcentagem',
#  'porco',
#  'pouco',
#  'presente',
#  'presidente',
#  'preso',
#  'preto',
#  'primo',
#  'principal',
#  'prioridade',
#  'problema',
#  'profundo',
#  'programa',
#  'projeto',
#  'pronto',
#  'provar',
#  'psicologia',
#  'pulsar',
#  'pulseira',
#  'páscoa',
#  'pássaro',
#  'pão',
#  'pêssego',
#  'pôr_do_sol',
#  'quadrado',
#  'qual',
#  'qualquer',
#  'quarta_feira',
#  'quebrar',
#  'queixo',
#  'quente',
#  'quinta_feira',
#  'química',
#  'rato',
#  'razão',
#  'rei',
#  'relatório',
#  'religião',
#  'respeito',
#  'respirar',
#  'resumir',
#  'reunião',
#  'revista',
#  'revisão',
#  'rezar',
#  'rico',
#  'rosa',
#  'roubar',
#  'roxo',
#  'ruim',
#  'rápido',
#  'saber',
#  'sair',
#  'salada',
#  'salvar',
#  'sanduíche',
#  'sapato',
#  'se',
#  'segredo',
#  'seguir',
#  'segunda_feira',
#  'seguro',
#  'semestre',
#  'sempre',
#  'sentar',
#  'sentir',
#  'sexo',
#  'sexta_feira',
#  'sim',
#  'simples',
#  'sino',
#  'sobrinho',
#  'sofrer',
#  'sol',
#  'soletrar',
#  'solicitar',
#  'solteiro',
#  'sopa',
#  'sorteio',
#  'sorvete',
#  'sozinho',
#  'suave',
#  'substituir',
#  'sucesso',
#  'sujo',
#  'sul',
#  'sumir',
#  'superior',
#  'surdo',
#  'sutiã',
#  'sábado',
#  'sério',
#  'tabela',
#  'também',
#  'tarde',
#  'tatuagem',
#  'teimoso',
#  'telescópio',
#  'tempo',
#  'teoria',
#  'ter',
#  'termômetro',
#  'tigre',
#  'todo_dia',
#  'tomada',
#  'tomate',
#  'total',
#  'tradição',
#  'trazer',
#  'trem',
#  'tribunal',
#  'troféu',
#  'técnico',
#  'tímido',
#  'um',
#  'universidade',
#  'urgente',
#  'urso',
#  'vaca',
#  'vagina',
#  'vazio',
#  'veado',
#  'vela',
#  'vencer',
#  'vender',
#  'vento',
#  'ver',
#  'verde',
#  'vergonha',
#  'verme',
#  'vermelho',
#  'vestido',
#  'vinho',
#  'violino',
#  'virgem',
#  'viver',
#  'vocabulário',
#  'vomitar',
#  'voz',
#  'xampu',
#  'xingar',
#  'zero',
#  'zíper'}
